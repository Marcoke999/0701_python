# %%
import os
file_path=os.path.abspath(__name__)
print(file_path)
current_dir_name = os.path.dirname(file_path)
print(current_dir_name)
filename = os.path.join(current_dir_name,'class.csv')
if os.path.isfile(filename):
    print("有這個檔案")
else:
    print("沒這個檔案")
# Out:
# /workspaces/0701_python/learn/__main__
# /workspaces/0701_python/learn
# 有這個檔案

# %%
import os
import csv
import random

file_path = os.path.abspath(__name__) #檔案的絕對位置
current_dir_name = os.path.dirname(file_path) #取得目前的目錄
file_position = os.path.join(current_dir_name,'data','peoples.csv') #操作檔案的絕對位置

with open('names.txt',encoding='utf-8') as file1:
    contents:str = file1.read()
    names:[str] = contents.split(sep='\n')
    peoples_names = random.choices(names,k=50)
peoples_names


peoples = []
for name in peoples_names:
    height = random.randint(150,190)
    weight = random.randint(50,90)
    BMI = weight / (height/100) ** 2
    if BMI >= 35:
        status = '重度肥胖'
    elif BMI >= 30:
        status = '中度肥胖'
    elif BMI >= 27:
        status = '輕度肥胖'
    elif BMI >= 24:
        status = '體重過重'
    elif BMI >= 18.5:
        status = '體重正常'
    else:
        status = '體重過輕'

    peoples.append({"姓名":name,
 '身高':height,
 '體重':weight,
 'BMI':round(BMI,2),
 '狀態':status})


with open(file_position,mode='w',newline='') as file2:
    writer = csv.DictWriter(file2,['姓名','身高','體重','BMI','狀態'])
    writer.writeheader()
    writer.writerows(peoples)

# %%
#自動關閉pile物件 就不用再打file.close()
with open(filename,mode='w',encoding='utf-8') as file:
    file.write("姓名,國文,英文,數學\n柯,100,100,None\n")

# %%
list={"姓名":"柯","國文":10,"數學":20}
list
# Out:
# {'姓名': '柯', '國文': 10, '數學': 20}

# %%
fruits=['apple','banana','orange']
fruits.append("shit")
count=fruits.count('apple')
fruits.remove('apple')
print(count)
print(fruits)
# Out:
# 1
# ['banana', 'orange', 'shit']

# %%
import random
with open("names.txt",encoding="utf-8")as file: #改350
    contents=file.read()
    names=contents.split(sep='\n')
    student_name=random.choices(names,k=350)
student_name
# Out:
# ['孫宜珊',
#  '張彥博',
#  '吳明妮',
#  '楊綺芬',
#  '聶心怡',
#  '陳信念',
#  '鄭奇翰',
#  '吳振瑋',
#  '黃麗美',
#  '許淑婷',
#  '黃必琪',
#  '尚偉倫',
#  '林佳慧',
#  '柯宜臻',
#  '郭淑真',
#  '林志成',
#  '郭舜昇',
#  '鄭佳玲',
#  '趙偉銘',
#  '楊易政',
#  '陳怡珊',
#  '李蓉瑞',
#  '高信宏',
#  '葉祖雄',
#  '簡美君',
#  '呂傑宣',
#  '臧怡君',
#  '游一鈺',
#  '陳得映',
#  '景歡燦',
#  '蔡偉成',
#  '郭淑真',
#  '黃奎紹',
#  '葉祖雄',
#  '王柏聖',
#  '柯韋成',
#  '林冠蕙',
#  '李蓉瑞',
#  '蘇婷婷',
#  '劉慧君',
#  '龐皓芳',
#  '方筠紹',
#  '陳怡伶',
#  '謝貞妃',
#  '龐皓芳',
#  '李美洋',
#  '游淑惠',
#  '賴佳雯',
#  '李政白',
#  '張彥博',
#  '趙家豪',
#  '鄧哲榮',
#  '蕭怡伶',
#  '郎慧萍',
#  '黃柏宇',
#  '姜琬婷',
#  '吳欣書',
#  '羅幸娥',
#  '黃柏宇',
#  '余宗儒',
#  '黃心航',
#  '高俊男',
#  '李政成',
#  '傅佳琳',
#  '溫法堯',
#  '陳信宏',
#  '王梅劭',
#  '黃佩玲',
#  '尚偉倫',
#  '杜明延',
#  '許淑婷',
#  '林昱芳',
#  '楊易政',
#  '陳倩潔',
#  '吳欣書',
#  '梁柏宇',
#  '胡芳瑜',
#  '方筠紹',
#  '王展人',
#  '黃奎紹',
#  '黃江旭',
#  '王梅劭',
#  '潘俊賢',
#  '陳志偉',
#  '黃名明',
#  '王人仰',
#  '柯宜臻',
#  '林康亮',
#  '林建宏',
#  '王士銘',
#  '馮淑芬',
#  '林淑安',
#  '陳奇瑄',
#  '翁鈺婷',
#  '黃柏宇',
#  '孫火清',
#  '林佳蓉',
#  '蒙淑惠',
#  '羅佩樺',
#  '楊火帆',
# ...

# %%
student=[]                            #超過300
for name in student_name:
    chinese = random.randint(50,100)
    math = random.randint(50,100)
    english = random.randint(50,100)
    student.append({"姓名":name,
                    "國文":chinese,
                    "數學":math,
                    "英文":english})
student
# Out:
# [{'姓名': '孫宜珊', '國文': 74, '數學': 81, '英文': 76},
#  {'姓名': '張彥博', '國文': 62, '數學': 70, '英文': 63},
#  {'姓名': '吳明妮', '國文': 81, '數學': 50, '英文': 81},
#  {'姓名': '楊綺芬', '國文': 91, '數學': 57, '英文': 92},
#  {'姓名': '聶心怡', '國文': 50, '數學': 76, '英文': 71},
#  {'姓名': '陳信念', '國文': 68, '數學': 100, '英文': 62},
#  {'姓名': '鄭奇翰', '國文': 80, '數學': 79, '英文': 58},
#  {'姓名': '吳振瑋', '國文': 90, '數學': 57, '英文': 65},
#  {'姓名': '黃麗美', '國文': 56, '數學': 55, '英文': 84},
#  {'姓名': '許淑婷', '國文': 68, '數學': 90, '英文': 54},
#  {'姓名': '黃必琪', '國文': 75, '數學': 79, '英文': 56},
#  {'姓名': '尚偉倫', '國文': 79, '數學': 78, '英文': 90},
#  {'姓名': '林佳慧', '國文': 50, '數學': 79, '英文': 90},
#  {'姓名': '柯宜臻', '國文': 78, '數學': 89, '英文': 74},
#  {'姓名': '郭淑真', '國文': 69, '數學': 59, '英文': 62},
#  {'姓名': '林志成', '國文': 68, '數學': 64, '英文': 68},
#  {'姓名': '郭舜昇', '國文': 66, '數學': 59, '英文': 66},
#  {'姓名': '鄭佳玲', '國文': 77, '數學': 76, '英文': 53},
#  {'姓名': '趙偉銘', '國文': 97, '數學': 93, '英文': 95},
#  {'姓名': '楊易政', '國文': 75, '數學': 83, '英文': 55},
# ...

# %%
import csv
with open(filename,mode='w',newline='')as file:
    writer = csv.DictWriter(file,['姓名','國文','英文','數學'])
    writer.writeheader()
    writer.writerows(student)

# %%
#HW11
import random
import csv
file_path=os.path.abspath(__name__)
print(file_path)
current_dir_name = os.path.dirname(file_path)
print(current_dir_name)
filename = os.path.join(current_dir_name,'HW.data','HW.csv')
with open("names.txt",encoding="utf-8")as file: 
    contents=file.read()
    names=contents.split(sep='\n')
    student_name=random.choices(names,k=50)
student_name


student=[]                            
for name in student_name:
    height= random.randint(150,190)
    weight = random.randint(50,90)
    student.append({"姓名":name,
                    "身高":height,
                    "體重":weight})
student
    

with open(filename,mode='w',newline='')as file:
    writer = csv.DictWriter(file,['姓名','身高','體重'])
    writer.writeheader()
    writer.writerows(student)
# Out:
# /workspaces/0701_python/learn/__main__
# /workspaces/0701_python/learn
